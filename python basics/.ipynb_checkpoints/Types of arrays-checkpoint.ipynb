# %% [markdown]
# # Array Types

# %% [markdown]
# signed char
#
#
#
#
#
#
#
#
#
#
# unsigned char
#
#
#
#
#
#
#
#
#
#
# Py_UNICODE
#
#
#
#
#
#
#
#
#
#
# signed sort
#
#
#
#
#
#
#
#
#
#
# unsigned sort
#
#
#
#
#
#
#
#
#
#
# signed int
#
#
#
#
#
#
#
#
#
#
# unsigned int
#
#
#
#
#
#
#
#
#
#
# signed long
#
#
#
#
#
#
#
#
#
#
# unsigned long
#
#
#
#
#
#
#
#
#
#
# float
#
#
#
#
#
#
#
#
#
#
# double
